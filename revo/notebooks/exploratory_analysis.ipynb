# %%
import pandas as pd

# %%
# Import cleaned data
df=pd.read_csv('output/final_df.csv')

# %%
df
# Out:
#        Country Net profit/total assets Total liabilities/total assets  \
# 0      Hungary                       m                              m
# 1       Poland                       0                           0.49
# 2      Hungary                    0.01                           0.78
# 3       Poland                   -0.02                           0.44
# 4       Poland                       0                              0
# ...        ...                     ...                            ...
# 7231  Slovakia                       m                              m
# 7232    Poland                   -0.15                          29.05
# 7233  Slovakia                       m                              m
# 7234    Poland                       0                              0
# 7235  Slovakia                       m                              m
#
#      Working capital/total assets Current assets/short-term liabilities  \
# ...
